# %% [markdown]
# # Red de comercio internacional

# %% [markdown]
# #### Comercio total

# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datos = pd.read_csv('ne2_e_2015sinWorldTotal.csv', sep = ',') # importación de datos en un data frame de pandas

# %%
datos.head()
# Out:
#    Source                     Target        Volume
# 0  Africa                     Africa   74411409704
# 1  Africa                       Asia  100508962460
# 2  Africa  Australia and New Zealand    1455388343
# 3  Africa                     Brazil    7264768606
# 4  Africa                      China   46798030247

# %%
G=nx.from_pandas_dataframe(datos, 'Source', 'Target', edge_attr=None, create_using=None) #construcción del grafo

# %%
G

# %%
# nodes
print G.nodes()[0:10]
# number of nodes
print "# nodes: ",G.number_of_nodes()

# edges
print G.edges()[0:10]
# number of edges
print "# edges: ",G.number_of_edges()
# Out:
# ['Brazil', 'Other CIS (CIS11)', 'Africa', 'Commonwealth of Independent States (CIS)', 'Asia', 'Middle East', 'Other Europe', 'Europe', 'Four East Asian traders', 'European Union (28)']
# # nodes:  22
# [('Brazil', 'Europe'), ('Brazil', 'South and Central America'), ('Brazil', 'Other CIS (CIS11)'), ('Brazil', 'Four East Asian traders'), ('Brazil', 'India'), ('Brazil', 'Other Europe'), ('Brazil', 'Mexico'), ('Brazil', 'Africa'), ('Brazil', 'Commonwealth of Independent States (CIS)'), ('Brazil', 'Asia')]
# # edges:  220

# %%
nx.connected_components(G)
# Out:
# <generator object connected_components at 0x000000000AC589D8>

# %%
# Degree
nx.degree(G)
# Out:
# {'Africa': 23,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 15,
#  'Commonwealth of Independent States (CIS)': 23,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 15,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 23,
#  'North America': 23,
#  'Other Africa': 15,
#  'Other Asia': 15,
#  'Other CIS (CIS11)': 15,
#  'Other Europe': 15,
#  'Russian Federation': 21,
#  'South Africa': 15,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G)
# Out:
# {'Africa': 1.0,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.7777777777777778,
#  'Commonwealth of Independent States (CIS)': 1.0,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.7777777777777778,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 1.0,
#  'North America': 1.0,
#  'Other Africa': 0.7777777777777778,
#  'Other Asia': 0.7777777777777778,
#  'Other CIS (CIS11)': 0.7777777777777778,
#  'Other Europe': 0.7777777777777778,
#  'Russian Federation': 1.0,
#  'South Africa': 0.7777777777777778,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G)
# Out:
# {'Africa': 0.006666666666666667,
#  'Asia': 0.006666666666666667,
#  'Australia and New Zealand': 0.006666666666666667,
#  'Brazil': 0.006666666666666667,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.006666666666666667,
#  'Europe': 0.006666666666666667,
#  'European Union (28)': 0.006666666666666667,
#  'Four East Asian traders': 0.006666666666666667,
#  'India': 0.0,
#  'Japan': 0.006666666666666667,
#  'Mexico': 0.006666666666666667,
#  'Middle East': 0.006666666666666667,
#  'North America': 0.006666666666666667,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.006666666666666667,
#  'South Africa': 0.0,
#  'South and Central America': 0.006666666666666667,
#  'United States': 0.006666666666666667}

# %%
# Clustering
nx.clustering(G)
# Out:
# {'Africa': 0.9,
#  'Asia': 0.9,
#  'Australia and New Zealand': 0.9,
#  'Brazil': 0.9,
#  'China': 1.0,
#  'Commonwealth of Independent States (CIS)': 0.9,
#  'Europe': 0.9,
#  'European Union (28)': 0.9,
#  'Four East Asian traders': 0.9,
#  'India': 1.0,
#  'Japan': 0.9,
#  'Mexico': 0.9,
#  'Middle East': 0.9,
#  'North America': 0.9,
#  'Other Africa': 1.0,
#  'Other Asia': 1.0,
#  'Other CIS (CIS11)': 1.0,
#  'Other Europe': 1.0,
#  'Russian Federation': 0.9,
#  'South Africa': 1.0,
#  'South and Central America': 0.9,
#  'United States': 0.9}

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
nx.draw_random(G, with_labels=True)
plt.show()

# %% [markdown]
# #### Industria automobiliaria y transpote

# %%
datos_auto = pd.read_csv('AutomotiveMashineryTransport.csv', sep = ',')

# %%
G_auto=nx.from_pandas_dataframe(datos_auto, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_auto, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_auto)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_auto)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_auto)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}

# %% [markdown]
# #### Alimentación y pescado

# %%
datos_food = pd.read_csv('AgricultFishFood.csv', sep = ',')

# %%
G_food=nx.from_pandas_dataframe(datos_food, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_food, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_food)
# Out:
# {'Africa': 23,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 15,
#  'Commonwealth of Independent States (CIS)': 23,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 15,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 23,
#  'North America': 23,
#  'Other Africa': 15,
#  'Other Asia': 15,
#  'Other CIS (CIS11)': 15,
#  'Other Europe': 15,
#  'Russian Federation': 21,
#  'South Africa': 15,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_food)
# Out:
# {'Africa': 1.0,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.7777777777777778,
#  'Commonwealth of Independent States (CIS)': 1.0,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.7777777777777778,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 1.0,
#  'North America': 1.0,
#  'Other Africa': 0.7777777777777778,
#  'Other Asia': 0.7777777777777778,
#  'Other CIS (CIS11)': 0.7777777777777778,
#  'Other Europe': 0.7777777777777778,
#  'Russian Federation': 1.0,
#  'South Africa': 0.7777777777777778,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_food)
# Out:
# {'Africa': 0.006666666666666667,
#  'Asia': 0.006666666666666667,
#  'Australia and New Zealand': 0.006666666666666667,
#  'Brazil': 0.006666666666666667,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.006666666666666667,
#  'Europe': 0.006666666666666667,
#  'European Union (28)': 0.006666666666666667,
#  'Four East Asian traders': 0.006666666666666667,
#  'India': 0.0,
#  'Japan': 0.006666666666666667,
#  'Mexico': 0.006666666666666667,
#  'Middle East': 0.006666666666666667,
#  'North America': 0.006666666666666667,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.006666666666666667,
#  'South Africa': 0.0,
#  'South and Central America': 0.006666666666666667,
#  'United States': 0.006666666666666667}

# %% [markdown]
# #### Pescado

# %%
datos_fish = pd.read_csv('Fish.csv', sep = ',')

# %%
G_fish=nx.from_pandas_dataframe(datos_fish, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_fish, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_fish)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_fish)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_fish)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}

# %% [markdown]
# #### Industria textil

# %%
datos_textil = pd.read_csv('TextilCloths.csv', sep = ',')

# %%
G_textil=nx.from_pandas_dataframe(datos_textil, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_textil, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_textil)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_textil)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_textil)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}

# %% [markdown]
# #### Industria química y farmaceutica

# %%
datos_pharma = pd.read_csv('ChemicalPharma.csv', sep = ',')

# %%
G_pharma=nx.from_pandas_dataframe(datos_pharma, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_pharma, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_pharma)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_pharma)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_pharma)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}

# %% [markdown]
# #### Electrónica

# %%
datos_electronic = pd.read_csv('Electronic.csv', sep = ',')

# %%
G_electronic=nx.from_pandas_dataframe(datos_electronic, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_electronic, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_electronic)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_electronic)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_electronic)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}

# %% [markdown]
# #### Industria energética

# %%
datos_fuel = pd.read_csv('Fuel.csv', sep = ',')

# %%
G_fuel=nx.from_pandas_dataframe(datos_fuel, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_fuel, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_fuel)
# Out:
# {'Africa': 23,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 15,
#  'Commonwealth of Independent States (CIS)': 23,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 15,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 23,
#  'North America': 23,
#  'Other Africa': 15,
#  'Other Asia': 15,
#  'Other CIS (CIS11)': 15,
#  'Other Europe': 15,
#  'Russian Federation': 21,
#  'South Africa': 15,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_fuel)
# Out:
# {'Africa': 1.0,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.7777777777777778,
#  'Commonwealth of Independent States (CIS)': 1.0,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.7777777777777778,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 1.0,
#  'North America': 1.0,
#  'Other Africa': 0.7777777777777778,
#  'Other Asia': 0.7777777777777778,
#  'Other CIS (CIS11)': 0.7777777777777778,
#  'Other Europe': 0.7777777777777778,
#  'Russian Federation': 1.0,
#  'South Africa': 0.7777777777777778,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_fuel)
# Out:
# {'Africa': 0.006666666666666667,
#  'Asia': 0.006666666666666667,
#  'Australia and New Zealand': 0.006666666666666667,
#  'Brazil': 0.006666666666666667,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.006666666666666667,
#  'Europe': 0.006666666666666667,
#  'European Union (28)': 0.006666666666666667,
#  'Four East Asian traders': 0.006666666666666667,
#  'India': 0.0,
#  'Japan': 0.006666666666666667,
#  'Mexico': 0.006666666666666667,
#  'Middle East': 0.006666666666666667,
#  'North America': 0.006666666666666667,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.006666666666666667,
#  'South Africa': 0.0,
#  'South and Central America': 0.006666666666666667,
#  'United States': 0.006666666666666667}

# %% [markdown]
# #### Investigación

# %%
datos_science = pd.read_csv('Science.csv', sep = ',')

# %%
G_science=nx.from_pandas_dataframe(datos_science, 'Source', 'Target', edge_attr=None, create_using=None)

# %%
nx.draw_random(G_science, with_labels=True)
plt.show()

# %%
# Degree
nx.degree(G_science)
# Out:
# {'Africa': 11,
#  'Asia': 23,
#  'Australia and New Zealand': 23,
#  'Brazil': 21,
#  'China': 11,
#  'Commonwealth of Independent States (CIS)': 11,
#  'Europe': 23,
#  'European Union (28)': 23,
#  'Four East Asian traders': 23,
#  'India': 11,
#  'Japan': 21,
#  'Mexico': 21,
#  'Middle East': 11,
#  'North America': 23,
#  'Other Africa': 11,
#  'Other Asia': 11,
#  'Other CIS (CIS11)': 11,
#  'Other Europe': 11,
#  'Russian Federation': 11,
#  'South Africa': 11,
#  'South and Central America': 23,
#  'United States': 21}

# %%
# Closeness
nx.closeness_centrality(G_science)
# Out:
# {'Africa': 0.6774193548387096,
#  'Asia': 1.0,
#  'Australia and New Zealand': 1.0,
#  'Brazil': 1.0,
#  'China': 0.6774193548387096,
#  'Commonwealth of Independent States (CIS)': 0.6774193548387096,
#  'Europe': 1.0,
#  'European Union (28)': 1.0,
#  'Four East Asian traders': 1.0,
#  'India': 0.6774193548387096,
#  'Japan': 1.0,
#  'Mexico': 1.0,
#  'Middle East': 0.6774193548387096,
#  'North America': 1.0,
#  'Other Africa': 0.6774193548387096,
#  'Other Asia': 0.6774193548387096,
#  'Other CIS (CIS11)': 0.6774193548387096,
#  'Other Europe': 0.6774193548387096,
#  'Russian Federation': 0.6774193548387096,
#  'South Africa': 0.6774193548387096,
#  'South and Central America': 1.0,
#  'United States': 1.0}

# %%
# Betweenness
nx.betweenness_centrality(G_science)
# Out:
# {'Africa': 0.0,
#  'Asia': 0.02380952380952382,
#  'Australia and New Zealand': 0.02380952380952382,
#  'Brazil': 0.02380952380952382,
#  'China': 0.0,
#  'Commonwealth of Independent States (CIS)': 0.0,
#  'Europe': 0.02380952380952382,
#  'European Union (28)': 0.02380952380952382,
#  'Four East Asian traders': 0.02380952380952382,
#  'India': 0.0,
#  'Japan': 0.02380952380952382,
#  'Mexico': 0.02380952380952382,
#  'Middle East': 0.0,
#  'North America': 0.02380952380952382,
#  'Other Africa': 0.0,
#  'Other Asia': 0.0,
#  'Other CIS (CIS11)': 0.0,
#  'Other Europe': 0.0,
#  'Russian Federation': 0.0,
#  'South Africa': 0.0,
#  'South and Central America': 0.02380952380952382,
#  'United States': 0.02380952380952382}
